# %% [markdown]
# # Домашнє завдання до теми "Розширені методи обробки даних у Pandas"

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Курс data analyst/Python/Pandas/Data/supermarket_sales.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. Відсортуйте дані за спаданням ціни товара ('Unit price') і виведіть 5 перших рядочків на екран.

# %%
df.sort_values(by = 'Unit price', ascending = False).head(5)
# Out:
#       Invoice ID Branch       City Customer type Gender         Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member   Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal   Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal   Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member   Male    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 930       99.92         6  29.976  629.496  3/24/2019  13:33      Ewallet
# 494       99.89         2   9.989  209.769  2/26/2019  11:48      Ewallet
# 283       99.83         6  29.949  628.929   3/4/2019  15:02      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 983  699.72                 4.761905        34.986     6.1
# 122  899.64                 4.761905        44.982     4.2
# 930  599.52                 4.761905        29.976     7.1
# 494  199.78                 4.761905         9.989     7.1
# 283  598.98                 4.761905        29.949     8.5

# %% [markdown]
# 2. Знайдіть інвойс (рядок в даних) в категорії товарів `Electronic accessories`, в якому був куплений товар з найбільшою кількістю і найбільшою ціною. Виведіть цей рядок даних на екран.

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df[df["Product line"] == "Electronic accessories"].sort_values(by = ['Quantity', 'Unit price'], ascending = [False, False]).head(1)
# Out:
#       Invoice ID Branch    City Customer type Gender            Product line  \
# 105  704-48-3927      A  Yangon        Member   Male  Electronic accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time  Payment   cogs  \
# 105       88.67        10  44.335  931.035  1/12/2019  14:50  Ewallet  886.7
#
#      gross margin percentage  gross income  Rating
# 105                 4.761905        44.335     7.3

# %% [markdown]
# 3.1. Створіть нову колонку в даних `Rating Category`, яка визначає категорію рейтингу (`Rating`): високий, середній чи низький за наступним правилом:
# - якщо рейтинг вищий або рівний 8 - то він високий (`High`)
# - якщо рейтинг від 6 (включно) до 8 (не включно) - то він середній (`Medium`)
# - інакше - низький (`Low`).

# %%
def rating_category(val):
  if val >= 8:
    return 'High'
  elif val>=6 and val<8:
    return 'Medium'
  else:
    return 'Low'

# %%
df['Rating Category'] = df['Rating'].apply(rating_category)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3
#
#   Rating Category
# 0            High
# 1            High
# 2          Medium
# 3            High
# 4             Low

# %% [markdown]
# 3.2. Виведіть, який відсоток даних становить кожне зі значень категорій рейтингу.

# %%
df["Rating Category"].value_counts(normalize =True)
# Out:
# Rating Category
# Medium    0.356
# High      0.329
# Low       0.315
# Name: proportion, dtype: float64

# %% [markdown]
# 4.1. Запустіть код нижче аби створити змінну `time`. Ця змінна містить час в форматі "година:хвилина". Напишіть функцію `get_hour`, яка буде зі змінної формату як `time` дістати лише години і конвертувати їх у тип `int`.
#
# Запустіть написану функцію на змінній `time` та перевірте правильність роботи функції.

# %%
time = '11:28'

# %%
def get_hour(time):
  time_int = int(time.split(":")[0])
  return time_int

# %%
get_hour('11:28')
# Out:
# 11

# %%
type(get_hour('11:28'))
# Out:
# int

# %% [markdown]
# 4.2. З допомогою функції `get_hour` і метода `DataFrame.apply()` створіть нову колонку `Hour` в нашому наборі даних, яка буде містити години здійснення покупки, обчислені на основі часу здійснення покупки `Time`.

# %%
df['Hour'] = df['Time'].apply(get_hour)

# %%
df.head(

)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3
#
#   Rating Category  Hour
# 0            High    13
# 1            High    10
# 2          Medium    13
# 3            High    20
# 4             Low    10

# %% [markdown]
# 4.3. Виведіть кількість значень за кожною годиною покупки і дайте відповідь "О яких годинах найбільше здійснюють покупок покупці і чому на Ваш погляд саме о цих годинах? Чи це слогічно, що найбільше покупок саме в ці години?".

# %%
df['Hour'].value_counts()
# Out:
# Hour
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# Name: count, dtype: int64

# %% [markdown]
# Найбільше покупок здійснювалося о 19 та 13 годині. Цей розподіл є логічним, оскільки роблять покупки після роботии або в обідній час. Було б цікаво подивитися на категорії покупок, які роблять в години піку.

# %%
df[df['Hour'] == 19]['Product line'].value_counts()
# Out:
# Product line
# Food and beverages        26
# Fashion accessories       24
# Sports and travel         20
# Electronic accessories    16
# Health and beauty         14
# Home and lifestyle        13
# Name: count, dtype: int64

# %%
df[df['Hour'] == 13]['Product line'].value_counts()
# Out:
# Product line
# Home and lifestyle        20
# Sports and travel         19
# Fashion accessories       19
# Health and beauty         17
# Food and beverages        15
# Electronic accessories    13
# Name: count, dtype: int64

# %% [markdown]
# Бачимо, що в обідній час найпопулярнішою категорією є їжа та напої. Тоді як у вечірній час господарські товари.

# %% [markdown]
# 5. Виведіть середнє значення чеку (`Total`) для покупок в містах, наявних в даних, за допомогою функції `groupby`.

# %%
df.groupby("City")['Total'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %% [markdown]
# 6. Виведіть кількість покупок, середнє, мінімальне та максимальне значення для загальної суми чеку (Total) в містах, наявних в даних, за допомогою функції groupby.
# Зробіть висновки з цих показників та дайте рекомендації для мережі супермаркетів.

# %%
df.groupby("City")['Total'].agg(['count', 'mean', 'min', 'max'])
# Out:
#            count        mean      min      max
# City
# Mandalay     332  319.872506  18.6375  1022.49
# Naypyitaw    328  337.099715  10.6785  1042.65
# Yangon       340  312.354031  12.6945  1039.29

# %% [markdown]
# Для Naypyitaw варто підтримувати асортимент товарів преміум-сегменту, або там роблять оптові закупівлі, оскільки там висока схильність покупців витрачати більше за один раз.
# Щоб зменшити кількість занадто дрібних чеків (10.68 у Naypyitaw), можна ввести акції на кшталт «Зроби покупку на суму від X — отримай знижку» або оптові пропозиції.

# %% [markdown]
# 7. Ми внесли деякі зміни в наш набір даних, тож, давайте запишемо результат у файл. Запишіть оновлену версію даних у файл `supermarket_sales_enriched.csv`. Зверніть увагу, аби не записати нічого зайвого, наприклад, індекси рядків нам в файлі не потрібні, оскільки вони стандартні.

# %%
df.to_csv('supermarket_sales_enriched.csv', index = False)

# %%
pd.read_csv("supermarket_sales_enriched.csv", index_col = 0)
# Out:
#             Branch       City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
# ...            ...        ...           ...     ...                     ...
# 233-67-5758      C  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227      B   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male      Food and beverages
# 347-56-2442      A     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female     Fashion accessories
#
#              Unit price  Quantity   Tax 5%      Total       Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415   548.9715   1/5/2019  13:08
# 226-31-3081       15.28         5   3.8200    80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155   340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880   489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085   634.3785   2/8/2019  10:37
# ...                 ...       ...      ...        ...        ...    ...
# 233-67-5758       40.35         1   2.0175    42.3675  1/29/2019  13:46
# 303-96-2227       97.38        10  48.6900  1022.4900   3/2/2019  17:16
# 727-02-1313       31.84         1   1.5920    33.4320   2/9/2019  13:22
# 347-56-2442       65.82         1   3.2910    69.1110  2/22/2019  15:33
# 849-09-3807       88.34         7  30.9190   649.2990  2/18/2019  13:28
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
# ...                  ...     ...                      ...           ...
# 233-67-5758      Ewallet   40.35                 4.761905        2.0175
# 303-96-2227      Ewallet  973.80                 4.761905       48.6900
# 727-02-1313         Cash   31.84                 4.761905        1.5920
# 347-56-2442         Cash   65.82                 4.761905        3.2910
# 849-09-3807         Cash  618.38                 4.761905       30.9190
#
#              Rating Rating Category  Hour
# Invoice ID
# 750-67-8428     9.1            High    13
# 226-31-3081     9.6            High    10
# 631-41-3108     7.4          Medium    13
# 123-19-1176     8.4            High    20
# 373-73-7910     5.3             Low    10
# ...             ...             ...   ...
# 233-67-5758     6.2          Medium    13
# 303-96-2227     4.4             Low    17
# 727-02-1313     7.7          Medium    13
# 347-56-2442     4.1             Low    15
# 849-09-3807     6.6          Medium    13
#
# [1000 rows x 18 columns]
